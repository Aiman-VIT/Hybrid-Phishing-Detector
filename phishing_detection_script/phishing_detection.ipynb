# %%
#importing all the required libraries
import hashlib
import os
import email
from bs4 import BeautifulSoup
import re
import json
import requests
from urllib.parse import urlparse,quote
from urlextract import URLExtract
import pandas as pd
import joblib

#import the custom classes from the seperate file to avoid retraining
from model_classes import SenderPatternFeatures, URLFeatureExtractor

#Load all API keys from .env file
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Define constants
EML_DIR = '../malicious_emails/'
WHITELIST_FILE = 'whitelist.json'
PHISHTANK_API_URL = "https://checkurl.phishtank.com/checkurl/"
USER_AGENT = "phishtank/PhishDet"

PHISHTANK_API_KEY = "" # Blank

VIRUSTOTAL_API_KEY = os.getenv("VIRUSTOTAL_API_KEY")
VIRUSTOTAL_URL = "https://www.virustotal.com/api/v3/files/"

# %%
# getting the from address, subject , body , and unique urls from an email file
def parse_emails(filepath) :
    with open (filepath, 'rb') as f:
        raw_email = f.read()

    msg = email.message_from_bytes(raw_email) #reads the file as raw bytes

    # extract subject
    subject_header = msg['Subject']
    if subject_header :
        subject_decoded = email.header.decode_header(subject_header)
        subject = ''
        for fragment , encoding in subject_decoded :
            if isinstance(fragment, bytes):
                try :
                    subject += fragment.decode(encoding or 'utf-8', errors='replace')
                except LookupError :
                    subject += fragment.decode('utf-8', errors='replace')
            else :
                subject += fragment
    else :
        subject = '(No Subject)'

    # extract from address
    from_addr = email.utils.parseaddr(msg.get('From'))[1]

    #extract body and urls
    body =''
    urls = [] #initialize empty list to store URLs
    extractor = URLExtract()

    for part in msg.walk() :
        content_type = part.get_content_type()

        # handling plaintext
        if content_type == 'text/plain':
            try:
                plain_text_content = part.get_payload(decode=True).decode(errors='replace')
                body += plain_text_content
                # Find URLs in the plain text part
                urls.extend(extractor.find_urls(plain_text_content))
            except:
                continue
            
        #handling html format
        elif content_type == 'text/html':
            try:
                html_content = part.get_payload(decode=True).decode(errors='replace')
                soup = BeautifulSoup(html_content, 'html.parser')
                # Add the text version to the body for ML analysis
                body += soup.get_text()
                # Find all <a> tags with an href attribute and extract the links
                for a_tag in soup.find_all('a', href=True):
                    urls.append(a_tag['href'])
            except :
                continue
    # remove duplicate urls
    unique_urls = list(set(urls))

    return from_addr, subject, body ,unique_urls, msg

# %%
#loading the whitelist file
def load_whitelist(filepath):
    with open(filepath, 'r') as f:
        whitelist = json.load(f)    
    return whitelist

# %%
#checking if the url is whitelisted or not
def is_white_listed(url, whitelist) :
    parsed = urlparse(url) #breaks down the input url into its components (like the protocol, domain, and path).
    domain = parsed.netloc #This extracts just the domain name (e.g., google.com) from the parsed URL. This is used for checking against domain-based whitelists.

    # exact URL match
    if url in whitelist.get('exactMatching', {}).get('url', []) :
        return True

    #domain match
    for whitelisted_domain in whitelist.get('domainMatching', {}).get('domain', []):
        if whitelisted_domain in domain:
            return True
    
    #domains in urls
    for domain_substring in whitelist.get('domainsInURLs', []):
        if domain_substring in url:
            return True
    
    return False

# %%
#phishtank API call to check if URL is malicious, suspicous or unknown
def check_phishtank(url):
    headers = {'User-Agent': USER_AGENT}
    payload = {
        'url': url,  # Do NOT encode with quote()
        'format': 'json'
    }
    if PHISHTANK_API_KEY:
        payload['app_key'] = PHISHTANK_API_KEY

    try:
        response = requests.post(PHISHTANK_API_URL, data=payload, headers=headers, timeout=10)
        print(f"Querying PhishTank for: {url}")
        print(f"Status code: {response.status_code}")
        if response.status_code == 200:
            data = response.json()
            print(f"PhishTank response: {data}")
            results = data.get('results', {})
            in_database = results.get('in_database', False)
            verified = results.get('verified', False)
            valid = results.get('valid', False)

            if in_database and verified and valid:
                return 'malicious'
            elif in_database and not verified:
                return 'suspicious'
            else:
                # URL not in database - treat as unknown, not safe
                return 'unknown'
        else:
            print(f" API call failed: {response.status_code}")
            return 'unknown'
    except Exception as e:
        print(f" Error querying PhishTank: {e}")
        return 'unknown'

# %%
#getting attachments from an email file
def extract_attachments(msg, save_dir='attachments'):
    attachments = []
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    for part in msg.walk():
        if part.get_content_maintype() == 'multipart':
            continue
        if part.get('Content-Disposition') is None:
            continue

        filename = part.get_filename()
        if filename:
            # Clean filename to avoid path issues
            safe_filename = re.sub(r'[<>:"/\\|?*]', '_', filename)
            filepath = os.path.join(save_dir, safe_filename)
            try:
                with open(filepath, "wb") as f:
                    f.write(part.get_payload(decode=True))
                attachments.append(filepath)
            except Exception as e:
                print(f"Error saving attachment {filename}: {e}")
    return attachments

# %%
#getting the the sha256 hash of a file
def get_file_sha256(filepath):
    sha256_hash = hashlib.sha256()
    with open(filepath, "rb") as f:
        for byte_block in iter(lambda: f.read(4096), b""):
            sha256_hash.update(byte_block)
    return sha256_hash.hexdigest()

# %%
#Virustotal API call  to check if the file is malicious or not
def check_virustotal(file_hash):
    headers = {
        "x-apikey": VIRUSTOTAL_API_KEY
    }
    url = VIRUSTOTAL_URL + file_hash
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            data = response.json()
            stats = data['data']['attributes']['last_analysis_stats']
            malicious_count = stats.get('malicious', 0)
            if malicious_count > 0:
                return 'malicious'
            else:
                return 'safe'
        elif response.status_code == 404:
            return 'unknown'  # File not found in VT database
        else:
            print(f" VirusTotal API error: {response.status_code}")
            return 'unknown'
    except Exception as e:
        print(f" Error checking VirusTotal: {e}")
        return 'unknown'

# %%
def ml_detection_check(from_addr, subject, body, urls):
    
    #Use ML model to detect phishing emails when blacklist checks fail
    
    try:
        # Load the trained model the pickled file made from ml training script
        model = joblib.load("../phishing_email_model_fixed.pkl")
        
        # Prepare data for ML model
        email_data = {
            'subject': subject,
            'body': body,
            'sender': from_addr,
            'urls': len(urls)
        }
        
        # Create DataFrame for prediction
        test_df = pd.DataFrame([email_data])
        
        # Make prediction
        prediction = model.predict(test_df)[0]
        prediction_proba = model.predict_proba(test_df)[0]
        confidence = max(prediction_proba) * 100
        
        # Determine result
        result = "PHISHING" if prediction == 1 else "LEGITIMATE"
        
        return result, confidence
        
    except Exception as e:
        print(f"Error in ML detection: {e}")
        return "ERROR", 0

# %%
if __name__ == '__main__':
    whitelist = load_whitelist(WHITELIST_FILE)

    if not os.path.exists(EML_DIR):
        print(f"Directory {EML_DIR} does not exist. Please create it and add it your .eml files.")
    else:
        eml_files = [f for f in os.listdir(EML_DIR) if f.endswith('.eml')]
        if not eml_files:
            print(f"Please add your .eml files to the {EML_DIR} directory for analysis.")
        else :
            for eml_file in eml_files:
                filepath = os.path.join(EML_DIR, eml_file)
                from_addr, subject, body, urls, msg = parse_emails(filepath)
                print(f"File : {eml_file}")
                print(f"From : {from_addr}")
                print(f"Subject : {subject}")
            
                #initial conditions
                email_status = 'SAFE'
                blacklist_failed = False

                #1. Phishtank check and whitelist url check
                print('BLACKLIST ANALYSIS:')
                print("Extracted URLs:")
                for url in urls:
                    print(f" - {url}")
                    if is_white_listed(url, whitelist):
                        print(" WHITELISTED - skipping analysis...")
                        continue
                    status = check_phishtank(url)
                    if status == 'malicious' :
                        print("! MALICIOUS URL DETECTED !")
                        email_status = 'MALICIOUS'
                    elif status == 'suspicious' :
                        print("! SUSPICIOUS URL DETECTED !")
                        email_status = 'MALICIOUS'
                    elif status == 'unknown' :
                        print(" ? URL NOT IN DATABASE ? requires further ML analysis...")
                        blacklist_failed = True
                
                #2. Virustotal attachment checking
                attachments = extract_attachments(msg)
                if attachments:
                    print("Attachments found:")
                    for attachment in attachments:
                        file_hash = get_file_sha256(attachment)
                        status = check_virustotal(file_hash)
                        if status == 'malicious':
                            print(f"Malicious attachment detected: {attachment}")
                            email_status = "MALICIOUS"
                        elif status == 'safe':
                            print(f"Attachment is safe: {attachment}")
                        else:
                            print(f"File Not Found in VirusTotal Database (Unknown): {attachment}")
                            blacklist_failed = True
                else:
                    print("No attachments found.")

                #3. ML Detection as Fallback
                if email_status != "MALICIOUS" and blacklist_failed:
                    print("\n ML DETECTION (Fallback):")
                    ml_result, confidence = ml_detection_check(from_addr, subject, body, urls)
                    if ml_result == "PHISHING":
                        print(f"ML Model detected PHISHING (Confidence: {confidence:.2f}%)")
                        email_status = "MALICIOUS"
                    elif ml_result == "LEGITIMATE":
                        print(f"ML Model detected LEGITIMATE (Confidence: {confidence:.2f}%)")
                    else:
                        print(f"ML detection error")
                
                # Final verdict
                print(f"\n FINAL VERDICT: {email_status}")
                if email_status == "MALICIOUS":
                    print("EMAIL IS MALICIOUS - TAKE ACTION!")
                else:
                    print("Email appears to be safe")
                
                print("\n" + "-"*60 + "\n")
# Out:
# File : sample-1.eml
# From : banco.bradesco@atendimento.com.br
# Subject : CLIENTE PRIME - BRADESCO LIVELO: Seu cartão tem 92.990 pontos LIVELO expirando hoje!
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - https://blog1seguimentmydomaine2bra.me/
# Querying PhishTank for: https://blog1seguimentmydomaine2bra.me/
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:42:13+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d635c5303354.82648285'}, 'results': {'url': 'https://blog1seguimentmydomaine2bra.me/', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected PHISHING (Confidence: 70.34%)
#
#  FINAL VERDICT: MALICIOUS
# EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# File : sample-10.eml
# From :
# Subject : Microsoft account unusual signin activity
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - mailto:sotrecognizd@gmail.com?&cc=sotrecognizd@gmail.com&Subject=Report+The+User
#  WHITELISTED - skipping analysis...
#  - mailto:sotrecognizd@gmail.com?&cc=sotrecognizd@gmail.com&Subject=Unsubscribe+me
#  WHITELISTED - skipping analysis...
#  - mailto:sotrecognizd@gmail.com?&cc=sotrecognizd@gmail.com&subject=unusual signin activity&body=Report The User
#  WHITELISTED - skipping analysis...
# No attachments found.
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-100.eml
# From : zonnepaneel@appjj.serenitepure.fr
# Subject : 🔋 Zonnepanelen voor een goede prijs
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - http://go.nltrck.com/?c=495&source=consumentenbond&s1=&lp=1190
# Querying PhishTank for: http://go.nltrck.com/?c=495&source=consumentenbond&s1=&lp=1190
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:42:15+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d635c7768da1.81417177'}, 'results': {'url': 'http://go.nltrck.com/?c=495&source=consumentenbond&s1=&lp=1190', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected PHISHING (Confidence: 72.26%)
#
#  FINAL VERDICT: MALICIOUS
# EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# File : sample-11.eml
# From : contact@123gereedschap.nl
# Subject : 💕 Bekijk deze mail alleen als je volwassen bent
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - https://safecloud.link/51fdd860-8ce0-4cf6-bf44-e5b29e312bb7/?rdm=6dnnhkrGmcwb&6dnnhkrGmcwb=phishing@pot&offerid=78420065
# Querying PhishTank for: https://safecloud.link/51fdd860-8ce0-4cf6-bf44-e5b29e312bb7/?rdm=6dnnhkrGmcwb&6dnnhkrGmcwb=phishing@pot&offerid=78420065
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:42:17+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d635c97a6ec7.84656081'}, 'results': {'url': 'https://safecloud.link/51fdd860-8ce0-4cf6-bf44-e5b29e312bb7/?rdm=6dnnhkrGmcwb&6dnnhkrGmcwb=phishing@pot&offerid=78420065', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected PHISHING (Confidence: 78.02%)
#
#  FINAL VERDICT: MALICIOUS
# EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# File : sample-12.eml
# From : do-not-reply@ses.binance.com
# Subject : [Binаnсе] lmmediate verification required for rodrigo-f-p@hotmail.com
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - https://zzdzw.com/
# Querying PhishTank for: https://zzdzw.com/
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:42:19+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d635cb652260.88767403'}, 'results': {'url': 'https://zzdzw.com/', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected LEGITIMATE (Confidence: 57.66%)
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-13.eml
# From : do-not-reply@ses.binance.com
# Subject : [Binаnсе] lmmediate verification required for rodrigo-f-p@hotmail.com
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - https://zzdzw.com/
# Querying PhishTank for: https://zzdzw.com/
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:42:21+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d635cd8a48d4.04395138'}, 'results': {'url': 'https://zzdzw.com/', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected LEGITIMATE (Confidence: 57.66%)
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-14.eml
# From : registration@and.co.uk
# Subject : Massive 400% Welcome Offer + 50 free spins awaits you when you open your account.
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - http://laredouteshop.com/cl/0_mt/3/4372/5451/0/0
# Querying PhishTank for: http://laredouteshop.com/cl/0_mt/3/4372/5451/0/0
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:42:23+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d635cfaf6a69.46232726'}, 'results': {'url': 'http://laredouteshop.com/cl/0_mt/3/4372/5451/0/0', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
#  - http://laredouteshop.com/oop/0_mt/3/4372/5292/0/0
# Querying PhishTank for: http://laredouteshop.com/oop/0_mt/3/4372/5292/0/0
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:42:25+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d
://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd4ZBaCo74bnPHtKJpILd5ZFX0PBCVCLouXpLm-zkFSVJHPpREKQbLlKbt-15boOGxft35otDABueE7oBTZDNkLNuD7BC0W7ZD-lox7w5B3oi44n4fBnOSKLy554OlaobMh2RkojZbw00SZ-m_xkGJjRNLtXQGVsoQW9jcaDkiqREcvZziVBqdOHKKHqG5d5wJZ8OYQfZ69Tt2kg0yUYlyPAY_pg75drS2dw8QNVFLKsHE6BL2Mu0TPZuOa-fetnSNN4rms7CSIjU7fiBYRzz0VuNVogtx8dnnEBD8yT1RoLlI8rqgRrKhv2jGWzSYujJqTZdK2cnE8M7PLX6llVArtc%3D
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:43:01+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d635f51163b8.46658912'}, 'results': {'url': 'https://links.ledger.com/u/click?_t=62c6a4ea5484430dbb7571e36c7bde50&_m=05e39c34e9844470a4886400a10772c8&_e=3jXjHxV-Dczx3ZByTYnjd4ZBaCo74bnPHtKJpILd5ZFX0PBCVCLouXpLm-zkFSVJHPpREKQbLlKbt-15boOGxft35otDABueE7oBTZDNkLNuD7BC0W7ZD-lox7w5B3oi44n4fBnOSKLy554OlaobMh2RkojZbw00SZ-m_xkGJjRNLtXQGVsoQW9jcaDkiqREcvZziVBqdOHKKHqG5d5wJZ8OYQfZ69Tt2kg0yUYlyPAY_pg75drS2dw8QNVFLKsHE6BL2Mu0TPZuOa-fetnSNN4rms7CSIjU7fiBYRzz0VuNVogtx8dnnEBD8yT1RoLlI8rqgRrKhv2jGWzSYujJqTZdK2cnE8M7PLX6llVArtc=', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected LEGITIMATE (Confidence: 84.43%)
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-18.eml
# From : metamask-updates-action@netwrksecurity.com
# Subject : Alerts
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - https://420.bio/NtRIA
# Querying PhishTank for: https://420.bio/NtRIA
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:43:02+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d635f67b8b62.68572138'}, 'results': {'url': 'https://420.bio/NtRIA', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected LEGITIMATE (Confidence: 61.87%)
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-19.eml
# From : ksimser@rmh.org
# Subject : AW
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - https://t.me/+pGV6aj_DOkQ1OWI0
# Querying PhishTank for: https://t.me/+pGV6aj_DOkQ1OWI0
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:43:03+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d635f7e30527.29932237'}, 'results': {'url': 'https://t.me/ pGV6aj_DOkQ1OWI0', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected LEGITIMATE (Confidence: 60.26%)
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-2.eml
# From : postmaster@digitalmashreq.mg.tdi.tc
# Subject : Confirm Your Mashreq Email Now For Your Security (MOVE TO INBOX)
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - tel:+971 4 424 4411
# Querying PhishTank for: tel:+971 4 424 4411
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:43:05+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68d635f9633998.31383636'}, 'errortext': 'You have supplied a malformed URL'}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
#  - https://www.bing.com/ck/a?!&&p=b03d939202acb382JmltdHM9MTY5NTE2ODAwMCZpZ3VpZD0wODI2ODBmNS1jMmZiLTZiZTAtMzM2ZS05Mzk5YzM3NzZhZGImaW5zaWQ9NTIzOQ&ptn=3&hsh=3&fclid=082680f5-c2fb-6be0-336e-9399c3776adb&psq=marhaba-travel.fr+site%3amarhaba-travel.com&u=a1aHR0cDovL21hcmhhYmEtdHJhdmVsLmNvbS9mci9mb3JtdWxlcw&ntb=1
#  WHITELISTED - skipping analysis...
#  - https://www.instagram.com/mashreq/
#  WHITELISTED - skipping analysis...
#  - https://twitter.com/MashreqTweets
#  WHITELISTED - skipping analysis...
#  - https://www.facebook.com/Mashreqbank/
#  WHITELISTED - skipping analysis...
#  - https://www.youtube.com/user/Mashreqbanklive
#  WHITELISTED - skipping analysis...
#  - https://www.linkedin.com/company/mashreqbank
#  WHITELISTED - skipping analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected LEGITIMATE (Confidence: 63.09%)
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-20.eml
# From : herb@southernheritagecc.com
# Subject : Earn XLM by staking your assets
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - Stellar.org
# Querying PhishTank for: Stellar.org
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:43:06+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68d635fabdf266.24890573'}, 'errortext': 'You have supplied a malformed URL'}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
#  - reserved.No
# Querying PhishTank for: reserved.No
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:43:07+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68d635fbe646f2.82222210'}, 'errortext': 'You have supplied a malformed URL'}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
#  - https://www.google.com/url?q=https%3A%2F%2Fblog3.stellarnewsletter.org%2F&sa=D&sntz=1&usg=AOvVaw3HKir80HlMUUT0h-Q7vHrV
#  WHITELISTED - skipping analysis...
#  - discretion.Safety
# Querying PhishTank for: discretion.Safety
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:43:09+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68d635fdb9d5f6.09479676'}, 'errortext': 'You have supplied a malformed URL'}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected LEGITIMATE (Confidence: 59.80%)
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-21.eml
# From : newsmail@app9l.serenitepure.fr
# Subject : Het begint weer warm te worden
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - http://secure-netcloud.com/?a=71&c=76&s1=dadaa&email=phishing@pot.org
#
# Querying PhishTank for: http://secure-netcloud.com/?a=71&c=76&s1=dadaa&email=phishing@pot.org
#
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:43:11+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d635ffb99252.99719991'}, 'results': {'url': 'http://secure-netcloud.com/?a=71&c=76&s1=dadaa&email=phishing@pot.org\n', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected PHISHING (Confidence: 73.36%)
#
#  FINAL VERDICT: MALICIOUS
# EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# File : sample-22.eml
# From : team@exodus.com
# Subject : Important changes to your Exodus wallet
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - Exodus.com/identify
# Querying PhishTank for: Exodus.com/identify
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:43:13+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68d63601b9cd22.51310035'}, 'errortext': 'You have supplied a malformed URL'}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
#  - https://pxlme.me/zAVvQVdl
# Querying PhishTank for: https://pxlme.me/zAVvQVdl
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:43:14+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d63602e5e9f4.02705533'}, 'results': {'url': 'https://pxlme.me/zAVvQVdl', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected PHISHING (Confidence: 51.35%)
#
#  FINAL VERDICT: MALICIOUS
# EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# File : sample-23.eml
# From : newsmail@appW3.serenitepure.fr
# Subject : Neem een kijkje op onze ontmoetingssite
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - http://secure-netcloud.com/?a=71&c=76&s1=dadaa&email=phishing@pot.org
#
# Querying PhishTank for: http://secure-netcloud.com/?a=71&c=76&s1=dadaa&email=phishing@pot.org
#
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:43:16+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68
Token=AQFzven6eoELvg&midSig=2zWFClSAZsU9Q1&trk=eml-jobs_jymbii_digest-jymbii-20-job_card_mercado&trkEmail=eml-jobs_jymbii_digest-jymbii-20-job_card_mercado-null-e2eu2o%7Ekrmoo7hr%7E8d-null-jobs%7Eview&lipi=urn%3Ali%3Apage%3Aemail_jobs_jymbii_digest%3BhBrLFygqQJyGD1ESdg4rqQ%3D%3D
#  WHITELISTED - skipping analysis...
#  - cloudlearning.eu
# Querying PhishTank for: cloudlearning.eu
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:43:21+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68d636095f3682.05986502'}, 'errortext': 'You have supplied a malformed URL'}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
#  - https://www.linkedin.com/e/v2?e=e2eu2o-krmoo7hr-8d&t=lun&midToken=AQFzven6eoELvg&midSig=2zWFClSAZsU9Q1&ek=jobs_jymbii_digest&li=60&m=unsub&ts=unsub&eid=e2eu2o-krmoo7hr-8d&loid=AQGruw0zwo2hyQAAAXrqSEaD_kYkHOuPvfe-j5exgRUxUalBQj6Sip_Mya7-WMck6HJjuW17ZldEtShT-7GAmoJhRMeWD3f21bp4
#  WHITELISTED - skipping analysis...
#  - https://www.linkedin.com/comm/jobs/alerts?midToken=AQFzven6eoELvg&midSig=2zWFClSAZsU9Q1&trk=eml-jobs_jymbii_digest-footer-29-manage_alert_mercado&trkEmail=eml-jobs_jymbii_digest-footer-29-manage_alert_mercado-null-e2eu2o%7Ekrmoo7hr%7E8d-null-job%7Ealert%7Emanager&lipi=urn%3Ali%3Apage%3Aemail_jobs_jymbii_digest%3BhBrLFygqQJyGD1ESdg4rqQ%3D%3D
#  WHITELISTED - skipping analysis...
#  - https://www.linkedin.com/comm/jobs?midToken=AQFzven6eoELvg&midSig=2zWFClSAZsU9Q1&trk=eml-jobs_jymbii_digest-jymbii-2-see_more_button_mercado&trkEmail=eml-jobs_jymbii_digest-jymbii-2-see_more_button_mercado-null-e2eu2o%7Ekrmoo7hr%7E8d-null-jobsHomeDirectory&lipi=urn%3Ali%3Apage%3Aemail_jobs_jymbii_digest%3BhBrLFygqQJyGD1ESdg4rqQ%3D%3D
#  WHITELISTED - skipping analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected LEGITIMATE (Confidence: 52.50%)
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-26.eml
# From :
# Subject : Someone tried to Iog in To Your Account, User lD : phishing@pot
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - mailto:unrecognized.suspicious.sign.in22@gmail.com?subject=Send+Statement rodrigo-f-p@hotmail.com
#  WHITELISTED - skipping analysis...
#  - mailto:<unrecognized.suspicious.sign.in22@gmail.com>?=bject=Unsubscribe+me!
#  WHITELISTED - skipping analysis...
#  - mailto:unrecognized.suspicious.sign.in22@gmail.com?subject=Yes+me phishing@pot.org
#  WHITELISTED - skipping analysis...
#  - https://www.facebook.com/n/?JohnCrestaniInternetJetset%2F&aref=1576263858332789&medium=email&mid=5999a3dc321a3G5af410968a6bG5999a87592475G3b4&n_m=phishing@pot.org
#  WHITELISTED - skipping analysis...
#  - https://www.facebook.com/email_forward_notice/?mid=5999a3dc321a3G5af410968a6bG5999a87592475G3b4
#  WHITELISTED - skipping analysis...
#  - https://www.facebook.com/n/?anamulhoquejamh&aref=1576263858332789&medium=email&mid=5999a3dc321a3G5af410968a6bG5999a87592475G3b4&n_m=phishing@pot.org
#  WHITELISTED - skipping analysis...
#  - mailto:<unrecognized.suspicious.sign.in22@gmail.com>
#  WHITELISTED - skipping analysis...
#  - https://www.facebook.com/n/?JohnCrestaniInternetJetset%2F&aref=1576263858332789&medium=email&mid=5999a3dc321a3G5af410968a6bG5999a87592475G3b4&n_m=phishing@pot@hotmail.com
#  WHITELISTED - skipping analysis...
# No attachments found.
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-27.eml
# From :
# Subject : Someone tried to Iog in To Your Account, User lD : phishing@pot
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - mailto:secure.international.alterts.1@gmail.com?subject=Yes+me phishing@pot.org
#  WHITELISTED - skipping analysis...
#  - mailto:<secure.international.alterts.1@gmail.com>
#  WHITELISTED - skipping analysis...
#  - mailto:<secure.international.alterts.1@gmail.com>?=bject=Unsubscribe+me!
#  WHITELISTED - skipping analysis...
#  - mailto:secure.international.alterts.1@gmail.com?subject=Send+Statement phishing@pot-p@hotmail.com
#  WHITELISTED - skipping analysis...
#  - https://www.facebook.com/n/?JohnCrestaniInternetJetset%2F&aref=1576263858332789&medium=email&mid=5999a3dc321a3G5af410968a6bG5999a87592475G3b4&n_m=phishing@pot.org
#  WHITELISTED - skipping analysis...
#  - https://www.facebook.com/email_forward_notice/?mid=5999a3dc321a3G5af410968a6bG5999a87592475G3b4
#  WHITELISTED - skipping analysis...
#  - https://www.facebook.com/n/?anamulhoquejamh&aref=1576263858332789&medium=email&mid=5999a3dc321a3G5af410968a6bG5999a87592475G3b4&n_m=phishing@pot.org
#  WHITELISTED - skipping analysis...
#  - https://www.facebook.com/n/?JohnCrestaniInternetJetset%2F&aref=1576263858332789&medium=email&mid=5999a3dc321a3G5af410968a6bG5999a87592475G3b4&n_m=phishing@pot@hotmail.com
#  WHITELISTED - skipping analysis...
# No attachments found.
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ...
#  ? URL NOT IN DATABASE ? requires further ML analysis...
#  - https://www.s1.mta1.max-sender.com/38eq3b6u3fe9w3efk3b2/836d.html
# Querying PhishTank for: https://www.s1.mta1.max-sender.com/38eq3b6u3fe9w3efk3b2/836d.html
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:47:41+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d6370d5f48c3.47260228'}, 'results': {'url': 'https://www.s1.mta1.max-sender.com/38eq3b6u3fe9w3efk3b2/836d.html', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
#  - https://www.s1.mta1.max-sender.com/1bcy1d0/3e17/21du1e0/819bs1f2.html
# Querying PhishTank for: https://www.s1.mta1.max-sender.com/1bcy1d0/3e17/21du1e0/819bs1f2.html
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:47:43+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d6370f29e8b5.15752283'}, 'results': {'url': 'https://www.s1.mta1.max-sender.com/1bcy1d0/3e17/21du1e0/819bs1f2.html', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
#  - opensea.io
# Querying PhishTank for: opensea.io
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:47:44+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68d63710ca8b61.87213592'}, 'errortext': 'You have supplied a malformed URL'}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
#  - https://www.s1.mta1.max-sender.com/df/f3m3d3ai140l103/80bey116.html
# Querying PhishTank for: https://www.s1.mta1.max-sender.com/df/f3m3d3ai140l103/80bey116.html
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:47:45+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d63711f19a92.88115012'}, 'results': {'url': 'https://www.s1.mta1.max-sender.com/df/f3m3d3ai140l103/80bey116.html', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected PHISHING (Confidence: 56.31%)
#
#  FINAL VERDICT: MALICIOUS
# EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# File : sample-88.eml
# From : mercadopagommo@hotmail.com
# Subject : Alerta de seguranca: verifique o acesso a sua conta do Mercado Pago Protocolo: 801002860
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - https://southamerica-east1-groovy-form-362414.cloudfunctions.net/lymercadolivre
# Querying PhishTank for: https://southamerica-east1-groovy-form-362414.cloudfunctions.net/lymercadolivre
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:47:47+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d63713e33d38.08177703'}, 'results': {'url': 'https://southamerica-east1-groovy-form-362414.cloudfunctions.net/lymercadolivre', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected PHISHING (Confidence: 58.63%)
#
#  FINAL VERDICT: MALICIOUS
# EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# File : sample-89.eml
# From : yssnsn@minecraftray.ru
# Subject : Hello how are you? Do you like beauty girl??
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - https://mail-api.app-sources.com/mail?t=click&p=-&r=aHR0cHM6Ly9jbG91ZGZhYXgucnUvbWk4Mw--
# Querying PhishTank for: https://mail-api.app-sources.com/mail?t=click&p=-&r=aHR0cHM6Ly9jbG91ZGZhYXgucnUvbWk4Mw--
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:47:49+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d63715943e83.29076715'}, 'results': {'url': 'https://mail-api.app-sources.com/mail?t=click&p=-&r=aHR0cHM6Ly9jbG91ZGZhYXgucnUvbWk4Mw--', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
#  - https://mail-api.app-sources.com/mail?t=click&p=&r=aHR0cHM6Ly9jbG91ZGZhYXgucnUvbWk4Mg--
# Querying PhishTank for: https://mail-api.app-sources.com/mail?t=click&p=&r=aHR0cHM6Ly9jbG91ZGZhYXgucnUvbWk4Mg--
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:47:50+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d63716d07844.65281726'}, 'results': {'url': 'https://mail-api.app-sources.com/mail?t=click&p=&r=aHR0cHM6Ly9jbG91ZGZhYXgucnUvbWk4Mg--', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected PHISHING (Confidence: 59.93%)
#
#  FINAL VERDICT: MALICIOUS
# EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# File : sample-9.eml
# From : noreply@firesonic.ca
# Subject : You sent 0.79 ETH via Ethereum network
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - https://www.bing.com/ck/a?!&&p=8cc5352d816ad678JmltdHM9MTY5NDA0NDgwMCZpZ3VpZD0xNTM1ZDczZS1lMDk0LTY2N2ItMmU0YS1jNDIzZTFjMjY3OGQmaW5zaWQ9NTE3Nw&ptn=3&hsh=3&fclid=1535d73e-e094-667b-2e4a-c423e1c2678d&psq=firesonic.ca&u=a1aHR0cHM6Ly9maXJlc29uaWMuY2Ev&ntb=1
#  WHITELISTED - skipping analysis...
# No attachments found.
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-90.eml
# From : contato@mercadolivre.com.br
# Subject : BLOQUEAMOS UM ACESSO SUSPEITO - PROTOCOLO: 283890577.
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - https://us-east1-valid-arc-109017.cloudfunctions.net/merc0109-12
# Querying PhishTank for: https://us-east1-valid-arc-109017.cloudfunctions.net/merc0109-12
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:47:52+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d63718dab591.04180486'}, 'results': {'url': 'https://us-east1-valid-arc-109017.cloudfunctions.net/merc0109-12', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected PHISHING (Confidence: 58.04%)
#
#  FINAL VERDICT: MALICIOUS
# EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# File : sample-91.eml
# From : newsmail@appHA.serenitepure.fr
# Subject : Ik hoop dat je die foto's leuk vindt: (8 foto's), (10 video's)..
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - http://safesecurelog.com/?a=75&c=146&s1=18OctoberrrINSTA&email=phishing@pot
# Querying PhishTank for: http://safesecurelog.com/?a=75&c=146&s1=18OctoberrrINSTA&email=phishing@pot
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:47:54+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d6371ac45900.14390111'}, 'results': {'url': 'http://safesecurelog.com/?a=75&c=146&s1=18OctoberrrINSTA&email=phishing@pot', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected PHISHING (Confidence: 68.21%)
#
#  FINAL VERDICT: MALICIOUS
# EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# File : sample-92.eml
# From : k4rlanauroski@gmail.com
# Subject : (No Subject)
# BLACKLIST ANALYSIS:
# Extracted URLs:
# Attachments found:
# Attachment is safe: attachments\nzHc3RSHv.pdf
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-93.eml
# From : naoresponder@mercadolivre.com.br
# Subject : Rodrigo Ferreira Peixoto, você removeu seu método de duas etapas?
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - https://ii-z2c6nzwc7a-rj.a.run.app/a/????????????????????????????????????????????????????????????????
# Querying PhishTank for: https://ii-z2c6nzwc7a-rj.a.run.app/a/????????????????????????????????????????????????????????????????
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:47:58+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d6371e282cf8.27891842'}, 'results': {'url': 'https://ii-z2c6nzwc7a-rj.a.run.app/a/????????????????????????????????????????????????????????????????', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected PHISHING (Confidence: 74.43%)
#
#  FINAL VERDICT: MALICIOUS
# EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# File : sample-94.eml
# From : Nellie.Horton@broadband.vi
# Subject : We have updated our Privacy
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - htTP://ntZtp0E8FcTgYIVtd.ertutoring.com/SAT-ACT-Prep/SAT/usr.php?e=phishing@pot&s=TeskPn8qEmvQ8vx6kdNcx4O9&a=OooZEBE35V6DLBcBZBjxL4VvQacbHoaf8iKa3Wk
# Querying PhishTank for: htTP://ntZtp0E8FcTgYIVtd.ertutoring.com/SAT-ACT-Prep/SAT/usr.php?e=phishing@pot&s=TeskPn8qEmvQ8vx6kdNcx4O9&a=OooZEBE35V6DLBcBZBjxL4VvQacbHoaf8iKa3Wk
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:47:59+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68d6371fa64586.53536124'}, 'errortext': 'You have supplied a malformed URL'}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected PHISHING (Confidence: 59.14%)
#
#  FINAL VERDICT: MALICIOUS
# EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# File : sample-95.eml
# From : 7wq1vg3kn9woejk4@emails.gorgias.com
# Subject : FWD: All unverified accounts will be suspended on 10/30/2022.
#  2hwpexn64bmc7qrzvo0kyduajlgf3598
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - https://usertest.sciquest.com/apps/Router/ExternalSiteTransition?url=https://drop-coin-availablenow.site44.com/
# Querying PhishTank for: https://usertest.sciquest.com/apps/Router/ExternalSiteTransition?url=https://drop-coin-availablenow.site44.com/
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:48:01+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d6372177fa04.55941860'}, 'results': {'url': 'https://usertest.sciquest.com/apps/Router/ExternalSiteTransition?url=https://drop-coin-availablenow.site44.com/', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
#  - mailto:customers@Trustwallet.com
# Querying PhishTank for: mailto:customers@Trustwallet.com
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:48:03+00:00', 'serverid': 'e5f3084e', 'status': 'error', 'requestid': '172.17.128.1.68d6372333a9f6.34988709'}, 'errortext': 'You have supplied a malformed URL'}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
#  - http://www.thinkific.com
# Querying PhishTank for: http://www.thinkific.com
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:48:04+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d6372458db44.26648316'}, 'results': {'url': 'http://www.thinkific.com', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected LEGITIMATE (Confidence: 59.89%)
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-96.eml
# From : jodykrier60@gmail.com
# Subject : ‼️🔔 Information in attachment
# BLACKLIST ANALYSIS:
# Extracted URLs:
# Attachments found:
# Attachment is safe: attachments\3spyWy0D.pdf
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-97.eml
# From : 051137@mca.sendmaster.online
# Subject : Bloqueio de conta 532543326 - ID YDW6NQYHNY
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - http://atendimentoajudadigital.online
# Querying PhishTank for: http://atendimentoajudadigital.online
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:48:07+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d6372772dfa6.34474416'}, 'results': {'url': 'http://atendimentoajudadigital.online', 'in_database': True, 'phish_id': 7907025, 'phish_detail_page': 'http://www.phishtank.com/phish_detail.php?phish_id=7907025', 'verified': False, 'verified_at': None, 'valid': False}}
# ! SUSPICIOUS URL DETECTED !
# No attachments found.
#
#  FINAL VERDICT: MALICIOUS
# EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
#
# File : sample-98.eml
# From : duckd@krasn-zoo.ru
# Subject : I am so lonely and so sexy. Why wouldn’t you write me?
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - https://shoutout.wix.com/so/6fOGU4P2D/c?w=2nsKgGlv8W78vvtNuXnb9Osljk238dvmlrpeiHjVbA0.eyJ1IjoiaHR0cHM6Ly9jbG91ZGZhYXgucnUvbWk5MCIsInIiOiJjODdhMDRjNC1hYzMwLTQyNTktMzhjNy0wNmU5MzBhZTVmNWQiLCJtIjoibWFpbCIsImMiOiIwMDAwMDAwMC0wMDAwLTAwMDAtMDAwMC0wMDAwMDAwMDAwMDAifQ
#  WHITELISTED - skipping analysis...
# No attachments found.
#
#  FINAL VERDICT: SAFE
# Email appears to be safe
#
# ------------------------------------------------------------
#
# File : sample-99.eml
# From : newsmail@appJv.serenitepure.fr
# Subject : Veel nieuwe aanmeldingen deze week
# BLACKLIST ANALYSIS:
# Extracted URLs:
#  - http://prvttrck.com/?a=76&c=156&s1=anna&email=phishing@pot
# Querying PhishTank for: http://prvttrck.com/?a=76&c=156&s1=anna&email=phishing@pot
# Status code: 200
# PhishTank response: {'meta': {'timestamp': '2025-09-26T06:48:09+00:00', 'serverid': 'e5f3084e', 'status': 'success', 'requestid': '172.17.128.1.68d63729525525.48819778'}, 'results': {'url': 'http://prvttrck.com/?a=76&c=156&s1=anna&email=phishing@pot', 'in_database': False}}
#  ? URL NOT IN DATABASE ? requires further ML analysis...
# No attachments found.
#
#  ML DETECTION (Fallback):
# ML Model detected PHISHING (Confidence: 69.21%)
#
#  FINAL VERDICT: MALICIOUS
# EMAIL IS MALICIOUS - TAKE ACTION!
#
# ------------------------------------------------------------
